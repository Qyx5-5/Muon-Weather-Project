# %% [markdown]
# ## Target: OrangePi/BearPi enabled collection
# ## Function:
# 1. matches time to parsed .txt files before (not including) 2024.2.16, convert to list of dict
# 2. convert data before (not including) 2024.2.16 to merged_data.csv
# 3. parse .txt files after 2024.2.16 to list of dict
# 4. put all data together in merged_data.csv

# %%
import re
import io

# Read the log file
with io.open('datalog/data_collection_2024-02-02.log', 'r') as file:
    log_file_contents = file.read()

def parse_log_file(log_file_contents):
    # Regular expression to match lines with serial data
    serial_data_pattern = re.compile(r"(\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2},\d{3}):INFO:Serial Data: (.*)")

    # List to hold parsed data
    parsed_data = []

    # Iterate over each line in the log file
    for line in log_file_contents.splitlines():
        # Search for serial data pattern
        match = serial_data_pattern.search(line)
        if match:
            # Extract timestamp and serial data
            timestamp = match.group(1)
            serial_data = match.group(2)
            # Store the extracted data
            parsed_data.append((timestamp, serial_data))

    return parsed_data

# Parse the log file
parsed_log_data = parse_log_file(log_file_contents)
parsed_log_data
# Out:
# [('2024-02-02 22:32:27,086', '0,141'),
#  ('2024-02-02 23:32:28,506', '0,142'),
#  ('2024-02-02 23:41:42,894', '0,2435'),
#  ('2024-02-02 23:42:00,886', '0,2439'),
#  ('2024-02-02 23:42:16,165', '0,2441'),
#  ('2024-02-02 23:42:27,387', '0,2446'),
#  ('2024-02-03 00:46:07,513', '0,4065'),
#  ('2024-02-03 01:46:11,485', '0,5695'),
#  ('2024-02-03 02:46:13,813', '0,7402'),
#  ('2024-02-03 03:46:16,779', '0,9148'),
#  ('2024-02-03 04:46:18,015', '0,10963'),
#  ('2024-02-03 05:46:20,350', '0,12594'),
#  ('2024-02-03 06:46:22,984', '0,14148'),
#  ('2024-02-03 07:46:26,753', '0,15502'),
#  ('2024-02-03 08:46:28,426', '0,16803'),
#  ('2024-02-03 09:46:30,164', '0,17994'),
#  ('2024-02-03 10:46:34,229', '0,19062'),
#  ('2024-02-03 11:46:44,527', '0,20127'),
#  ('2024-02-03 12:46:47,858', '0,21209'),
#  ('2024-02-03 13:46:49,180', '0,22339'),
#  ('2024-02-03 14:46:54,581', '0,23542'),
#  ('2024-02-03 15:46:57,215', '0,24710'),
#  ('2024-02-03 16:47:00,080', '0,25905'),
#  ('2024-02-03 17:47:01,709', '0,27092'),
#  ('2024-02-03 18:47:06,257', '0,28216'),
#  ('2024-02-03 19:47:23,980', '0,29333'),
#  ('2024-02-03 20:47:26,385', '0,30571'),
#  ('2024-02-03 21:47:28,636', '0,31931'),
#  ('2024-02-03 22:47:30,891', '0,33402'),
#  ('2024-02-03 23:47:33,776', '0,34682'),
#  ('2024-02-04 00:47:36,772', '0,35969'),
#  ('2024-02-04 01:47:39,774', '0,37284'),
#  ('2024-02-04 02:47:40,850', '0,38722'),
#  ('2024-02-04 03:47:43,835', '0,40075'),
#  ('2024-02-04 04:47:48,107', '0,41582'),
#  ('2024-02-04 05:47:49,583', '0,42835'),
#  ('2024-02-04 06:47:51,225', '0,44546'),
#  ('2024-02-04 07:47:56,563', '0,46183'),
#  ('2024-02-13 16:02:16,061', '5,23794'),
#  ('2024-02-13 17:02:19,543', '5,24777'),
#  ('2024-02-13 18:02:28,273', '5,25782'),
#  ('2024-02-13 19:02:31,189', '5,26737'),
#  ('2024-02-13 20:02:34,729', '5,27738'),
#  ('2024-02-13 21:02:36,133', '5,28746'),
#  ('2024-02-13 22:02:39,306', '5,29782'),
#  ('2024-02-13 23:02:45,047', '5,30864'),
#  ('2024-02-14 00:02:47,164', '5,31920'),
#  ('2024-02-14 01:02:52,224', '5,32971'),
#  ('2024-02-14 02:03:04,824', '5,34000'),
#  ('2024-02-14 03:03:06,838', '5,35053'),
#  ('2024-02-14 04:03:16,417', '5,36068'),
#  ('2024-02-14 05:03:19,893', '5,37126'),
#  ('2024-02-14 06:03:29,539', '5,38145'),
#  ('2024-02-14 07:03:32,188', '5,39252'),
#  ('2024-02-14 08:03:39,456', '5,40279'),
#  ('2024-02-14 09:03:40,626', '5,41296'),
#  ('2024-02-14 10:03:46,762', '5,42296'),
#  ('2024-02-14 11:03:58,574', '5,43321'),
#  ('2024-02-14 12:04:00,592', '5,44298'),
#  ('2024-02-14 13:04:02,648', '5,45320'),
#  ('2024-02-14 14:04:09,082', '5,46314'),
#  ('2024-02-14 15:04:10,692', '5,47345'),
#  ('2024-02-14 16:04:16,095', '5,48319'),
#  ('2024-02-14 17:04:19,261', '5,49321'),
#  ('2024-02-14 18:04:21,885', '5,50295'),
#  ('2024-02-14 19:04:26,171', '5,51274'),
#  ('2024-02-14 20:04:31,766', '5,52260'),
#  ('2024-02-14 21:04:36,228', '5,53254'),
#  ('2024-02-14 22:04:42,624', '5,54310'),
#  ('2024-02-14 23:04:45,084', '5,55368'),
#  ('2024-02-15 00:04:46,770', '5,56360'),
#  ('2024-02-15 01:04:49,545', '5,57388'),
#  ('2024-02-15 02:04:51,513', '5,58466'),
#  ('2024-02-15 03:04:54,857', '5,59524'),
#  ('2024-02-15 04:05:00,015', '6,525'),
#  ('2024-02-15 05:05:01,857', '6,1582'),
#  ('2024-02-15 06:05:03,320', '6,2536'),
#  ('2024-02-15 07:05:05,899', '6,3632'),
#  ('2024-02-15 08:05:07,476', '6,4628'),
#  ('2024-02-15 09:05:18,275', '6,5610'),
#  ('2024-02-15 10:05:33,498', '6,6550'),
#  ('2024-02-15 11:05:34,621', '6,7466'),
#  ('2024-02-15 12:05:42,548', '6,8431'),
#  ('2024-02-15 13:05:45,123', '6,9407'),
#  ('2024-02-15 14:05:48,572', '6,10335'),
#  ('2024-02-15 15:05:52,647', '6,11288'),
#  ('2024-02-15 16:05:56,698', '6,12349'),
#  ('2024-02-15 17:06:01,670', '6,13376'),
#  ('2024-02-15 18:06:02,814', '6,14377'),
#  ('2024-02-15 19:06:04,500', '6,15398')]

# %%
import os
import io

def parse_environmental_data_file(directory):
    # use os.listdir to get all files in the directory
    files = os.listdir(directory)    

    # List to hold parsed environmental data
    parsed_environmental_data = []

    # loop through all files
    for file in files:
        # construct full file path
        file_path = os.path.join(directory, file)

        # open, read, and parse the file
        with io.open(file_path, 'r') as file:
            collected_data_str = file.read()
            parsed_data = parse_environmental_data(collected_data_str)
            parsed_environmental_data.extend(parsed_data)

    return parsed_environmental_data


def parse_environmental_data(env_data_str):
    # Split the string into blocks of data for each serial entry
    data_blocks = env_data_str.strip().split("Serial Data: ")[1:]

    # List to hold parsed environmental data
    parsed_env_data = []

    # Iterate over each block and extract the information
    for block in data_blocks:
        lines = block.strip().split("\n")
        serial_data = lines[0].strip()
        city_name = lines[1].split(":")[1].strip()
        location_id = lines[2].split(":")[1].strip()
        temperature = lines[3].split(":")[1].strip()
        weather = lines[4].split(":")[1].strip()
        try:
            aqi = int(lines[5].split(":")[1].strip())
        except ValueError:
            aqi = None
        primary_pollutant = lines[6].split(":")[1].strip()

        parsed_env_data.append({
            "serial": serial_data,
            "city": city_name,
            "location_id": location_id,
            "temperature": temperature,
            "weather": weather,
            "aqi": aqi,
            "pollutant": primary_pollutant
        })

    return parsed_env_data


# Usage example:
directory = 'raw_data/before 2.15(inclusive)'
parsed_environmental_data = parse_environmental_data_file(directory)
parsed_environmental_data
# Out:
# [{'serial': '2,13796',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '2,15384',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '2,17305',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '2,19231',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '2,21141',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '2,22920',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '2,25079',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '2,27004',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '2,28366',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '2,29684',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'serial': '2,30859',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'serial': '2,31939',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '2,32968',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '2,34016',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'serial': '2,35311',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'serial': '2,36689',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'serial': '2,38201',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'serial': '2,39676',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'serial': '2,41040',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 30,
#   'pollutant': 'NA'},
#  {'serial': '2,42574',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 50,
#   'pollutant': 'NA'},
#  {'serial': '2,44168',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 61,
#   'pollutant': 'PM10'},
#  {'serial': '2,45901',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 59,
#   'pollutant': 'PM2.5'},
#  {'serial': '2,47642',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 34,
#   'pollutant': 'NA'},
#  {'serial': '2,49341',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '3,20714',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,21858',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 69,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,23139',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 65,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,24569',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 63,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,25866',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 55,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,27119',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 57,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,28582',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 60,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,29882',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 59,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,31051',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 53,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,32095',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 57,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,33187',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 70,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,34269',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,35268',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 80,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,36295',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 82,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,37370',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,38601',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': 67,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,39776',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 51,
#   'pollutant': 'PM10'},
#  {'serial': '3,40998',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 49,
#   'pollutant': 'NA'},
#  {'serial': '3,42339',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 43,
#   'pollutant': 'NA'},
#  {'serial': '3,43681',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 29,
#   'pollutant': 'NA'},
#  {'serial': '3,44900',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 35,
#   'pollutant': 'NA'},
#  {'serial': '3,46196',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '3,47593',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'serial': '3,48860',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '2,51120',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'serial': '2,53112',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'serial': '2,55269',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '2,57491',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '2,58725',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '2,59834',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '3,1034',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 21,
#   'pollutant': 'NA'},
#  {'serial': '3,2116',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 20,
#   'pollutant': 'NA'},
#  {'serial': '3,3134',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 19,
#   'pollutant': 'NA'},
#  {'serial': '3,4137',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '多云',
#   'aqi': 20,
#   'pollutant': 'NA'},
#  {'serial': '3,5135',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'serial': '3,6139',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '3,7154',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'serial': '3,8177',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '3,9157',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'serial': '3,10251',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'serial': '3,11347',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'serial': '3,12437',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'serial': '3,13572',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 32,
#   'pollutant': 'NA'},
#  {'serial': '3,14693',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 51,
#   'pollutant': 'PM10'},
#  {'serial': '3,15855',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 58,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,17057',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 69,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,18263',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,19496',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 79,
#   'pollutant': 'PM2.5'},
#  {'serial': '0,226',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 18,
#   'pollutant': 'NA'},
#  {'serial': '0,227',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 18,
#   'pollutant': 'NA'},
#  {'serial': '0,228',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 18,
#   'pollutant': 'NA'},
#  {'serial': '0,229',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 18,
#   'pollutant': 'NA'},
#  {'serial': '1,42260',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 88,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,43586',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 90,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,45041',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 94,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,46462',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 98,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,48109',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '阴',
#   'aqi': 97,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,49647',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '阴',
#   'aqi': 93,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,51437',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 87,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,53102',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 88,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,54509',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 84,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,55637',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 53,
#   'pollutant': 'PM2.5'},
#  {'serial': '1,56763',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '1,57833',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '1,58873',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '1,59897',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'serial': '2,1027',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '2,2180',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '2,3370',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '2,4568',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'serial': '2,5765',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'serial': '2,7085',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '2,8352',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '2,9755',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '2,11279',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '2,12446',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '5,56360',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '多云',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'serial': '5,57388',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '多云',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '5,58466',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '阴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '5,59524',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '多云',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '6,525',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '6,1582',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '多云',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'serial': '6,2536',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '多云',
#   'aqi': 20,
#   'pollutant': 'NA'},
#  {'serial': '6,3632',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '晴',
#   'aqi': 20,
#   'pollutant': 'NA'},
#  {'serial': '6,4628',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '晴',
#   'aqi': 18,
#   'pollutant': 'NA'},
#  {'serial': '6,5610',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 18,
#   'pollutant': 'NA'},
#  {'serial': '6,6550',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 19,
#   'pollutant': 'NA'},
#  {'serial': '6,7466',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '6,8431',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '6,9407',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '6,10335',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '6,11288',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'serial': '6,12349',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '6,13376',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': 30,
#   'pollutant': 'NA'},
#  {'serial': '6,14377',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 35,
#   'pollutant': 'NA'},
#  {'serial': '6,15398',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 39,
#   'pollutant': 'NA'},
#  {'serial': '0,98',
#   'city': '2024-02-15',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,105',
#   'city': '2024-02-15',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,109',
#   'city': '2024-02-15',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,113',
#   'city': '2024-02-15',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,148',
#   'city': '2024-02-15 21',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,151',
#   'city': '2024-02-15 21',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,156',
#   'city': '2024-02-15 21',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,159',
#   'city': '2024-02-15 22',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,245',
#   'city': '2024-02-15 22',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,249',
#   'city': '2024-02-15 22',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '1°C',
#   'aqi': None,
#   'pollutant': '45'},
#  {'serial': '0,1522',
#   'city': '2024-02-15 23',
#   'location_id': '海淀',
#   'temperature': '101010200',
#   'weather': '4°C',
#   'aqi': None,
#   'pollutant': '50'},
#  {'serial': '4,43831',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,44807',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 70,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,45820',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 68,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,46792',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 68,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,47762',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 67,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,48787',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 59,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,49803',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 58,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,50823',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 64,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,51845',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 68,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,52842',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 72,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,53841',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 87,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,54819',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 95,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,55793',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 122,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,56798',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 134,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,57840',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 128,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,58933',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 130,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,59941',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 129,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,1008',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 130,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,2077',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 132,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,3078',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 132,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,4079',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 130,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,5175',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 135,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,6219',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 140,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,7264',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 138,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,8256',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 125,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,9254',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 124,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,10388',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 128,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,11457',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 129,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,12487',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 128,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,13567',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 123,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,14653',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 118,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,15716',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 115,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,16721',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 117,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,17725',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 122,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,18757',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': 139,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,19734',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '晴',
#   'aqi': 153,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,20768',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '12°C',
#   'weather': '晴',
#   'aqi': 153,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,21751',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '14°C',
#   'weather': '晴',
#   'aqi': 148,
#   'pollutant': 'PM2.5'},
#  {'serial': '5,22794',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '15°C',
#   'weather': '晴',
#   'aqi': 139,
#   'pollutant': 'PM2.5'},
#  {'serial': '5

#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 63,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,37652',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': 70,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,38733',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 74,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,39763',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,40759',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,41775',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 83,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,42807',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 85,
#   'pollutant': 'PM2.5'},
#  {'serial': '3,50049',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '3,51336',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'serial': '3,52820',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '3,54198',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '3,55612',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 30,
#   'pollutant': 'NA'},
#  {'serial': '3,57008',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'serial': '3,58653',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'serial': '4,489',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'serial': '4,1868',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'serial': '4,2957',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'serial': '4,3977',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'serial': '4,4990',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 31,
#   'pollutant': 'NA'},
#  {'serial': '4,5975',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 33,
#   'pollutant': 'NA'},
#  {'serial': '4,7015',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 34,
#   'pollutant': 'NA'},
#  {'serial': '4,8138',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 34,
#   'pollutant': 'NA'},
#  {'serial': '4,9363',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 36,
#   'pollutant': 'NA'},
#  {'serial': '4,10432',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 36,
#   'pollutant': 'NA'},
#  {'serial': '4,11534',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 45,
#   'pollutant': 'NA'},
#  {'serial': '4,12634',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 56,
#   'pollutant': 'PM10'},
#  {'serial': '4,13674',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 74,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,14827',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 79,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,15920',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 77,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,17044',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 80,
#   'pollutant': 'PM2.5'},
#  {'serial': '4,18099',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 82,
#   'pollutant': 'PM2.5'}]

# %%
# Function to match and merge data
def match_and_merge_data(parsed_data, environmental_data):
    # Create a dictionary for quick lookup of environmental data by serial number
    env_data_by_serial = {data["serial"]: data for data in environmental_data}

    # List to hold merged data
    merged_data = []

    # Iterate over parsed data and merge with environmental data
    for timestamp, serial in parsed_data:
        if serial in env_data_by_serial:
            # Combine data
            combined_data = {
                "timestamp": timestamp,
                "serial": serial,
                **env_data_by_serial[serial]
            }
            merged_data.append(combined_data)

    return merged_data

# Perform the matching and merging
merged_data = match_and_merge_data(parsed_log_data, parsed_environmental_data)
merged_data
# Out:
# [{'timestamp': '2024-02-02 22:32:27,086',
#   'serial': '0,141',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 95,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-02 23:32:28,506',
#   'serial': '0,142',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 87,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-02 23:41:42,894',
#   'serial': '0,2435',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-02 23:42:00,886',
#   'serial': '0,2439',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-02 23:42:16,165',
#   'serial': '0,2441',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-02 23:42:27,387',
#   'serial': '0,2446',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 00:46:07,513',
#   'serial': '0,4065',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 79,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 01:46:11,485',
#   'serial': '0,5695',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 77,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 02:46:13,813',
#   'serial': '0,7402',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 67,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 03:46:16,779',
#   'serial': '0,9148',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 67,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 04:46:18,015',
#   'serial': '0,10963',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 70,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 05:46:20,350',
#   'serial': '0,12594',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-8°C',
#   'weather': '多云',
#   'aqi': 72,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 06:46:22,984',
#   'serial': '0,14148',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-8°C',
#   'weather': '晴',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 07:46:26,753',
#   'serial': '0,15502',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-8°C',
#   'weather': '晴',
#   'aqi': 73,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 08:46:28,426',
#   'serial': '0,16803',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-7°C',
#   'weather': '晴',
#   'aqi': 67,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 09:46:30,164',
#   'serial': '0,17994',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 65,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 10:46:34,229',
#   'serial': '0,19062',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '多云',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 11:46:44,527',
#   'serial': '0,20127',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 79,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 12:46:47,858',
#   'serial': '0,21209',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 74,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 13:46:49,180',
#   'serial': '0,22339',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 65,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 14:46:54,581',
#   'serial': '0,23542',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 63,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 15:46:57,215',
#   'serial': '0,24710',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 61,
#   'pollutant': 'PM10'},
#  {'timestamp': '2024-02-03 16:47:00,080',
#   'serial': '0,25905',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 60,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 17:47:01,709',
#   'serial': '0,27092',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 70,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 18:47:06,257',
#   'serial': '0,28216',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '阴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 19:47:23,980',
#   'serial': '0,29333',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '阴',
#   'aqi': 84,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 20:47:26,385',
#   'serial': '0,30571',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '阴',
#   'aqi': 99,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 21:47:28,636',
#   'serial': '0,31931',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 120,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 22:47:30,891',
#   'serial': '0,33402',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 128,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-03 23:47:33,776',
#   'serial': '0,34682',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 127,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 00:47:36,772',
#   'serial': '0,35969',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 123,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 01:47:39,774',
#   'serial': '0,37284',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 102,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 02:47:40,850',
#   'serial': '0,38722',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 98,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 03:47:43,835',
#   'serial': '0,40075',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 99,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 04:47:48,107',
#   'serial': '0,41582',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 104,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 05:47:49,583',
#   'serial': '0,42835',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 80,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 06:47:51,225',
#   'serial': '0,44546',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '阴',
#   'aqi': 74,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 07:47:56,563',
#   'serial': '0,46183',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '阴',
#   'aqi': 84,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 08:47:58,668',
#   'serial': '0,47566',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '阴',
#   'aqi': 110,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 09:48:00,741',
#   'serial': '0,48895',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 132,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 10:48:02,674',
#   'serial': '0,50066',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 127,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 11:48:05,230',
#   'serial': '0,51297',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '多云',
#   'aqi': 119,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 12:48:06,359',
#   'serial': '0,52536',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '阴',
#   'aqi': 108,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 13:48:08,789',
#   'serial': '0,53763',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '阴',
#   'aqi': 107,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 14:48:10,999',
#   'serial': '0,55024',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '阴',
#   'aqi': 107,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 15:48:14,062',
#   'serial': '0,56296',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '阴',
#   'aqi': 107,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 16:48:15,417',
#   'serial': '0,57550',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '阴',
#   'aqi': 105,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 17:48:18,153',
#   'serial': '0,58816',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '阴',
#   'aqi': 115,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 18:48:20,040',
#   'serial': '1,52',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '多云',
#   'aqi': 122,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 19:48:21,496',
#   'serial': '1,1263',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '多云',
#   'aqi': 135,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 20:48:24,142',
#   'serial': '1,2476',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '多云',
#   'aqi': 138,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 21:48:29,981',
#   'serial': '1,3833',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 138,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 22:48:33,506',
#   'serial': '1,5198',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 125,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-04 23:48:36,955',
#   'serial': '1,6491',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 125,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 00:48:38,394',
#   'serial': '1,8320',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 120,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 01:48:39,718',
#   'serial': '1,10619',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 118,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 02:48:41,409',
#   'serial': '1,13298',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 125,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 03:48:43,333',
#   'serial': '1,15876',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 128,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 04:48:47,723',
#   'serial': '1,18311',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 119,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 05:48:49,162',
#   'serial': '1,20531',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': 112,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 06:48:50,839',
#   'serial': '1,22317',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': 109,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 07:48:58,398',
#   'serial': '1,23685',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '阴',
#   'aqi': 103,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 08:49:00,292',
#   'serial': '1,24893',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '阴',
#   'aqi': 98,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 09:49:03,323',
#   'serial': '1,26046',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '阴',
#   'aqi': 102,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 10:49:09,094',
#   'serial': '1,27167',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '阴',
#   'aqi': 110,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 11:49:10,785',
#   'serial': '1,28268',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': 113,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 12:49:16,373',
#   'serial': '1,29245',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '多云',
#   'aqi': 79,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 13:49:20,930',
#   'serial': '1,30257',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '多云',
#   'aqi': 62,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 14:49:24,435',
#   'serial': '1,31243',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '多云',
#   'aqi': 62,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 15:49:33,821',
#   'serial': '1,32299',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '多云',
#   'aqi': 74,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 16:49:40,025',
#   'serial': '1,33410',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 17:49:44,641',
#   'serial': '1,34538',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 18:49:46,758',
#   'serial': '1,35589',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 74,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 19:49:49,092',
#   'serial': '1,36593',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 74,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 20:49:54,304',
#   'serial': '1,37663',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 64,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 21:49:58,570',
#   'serial': '1,38724',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 63,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 22:50:01,790',
#   'serial': '1,39855',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '多云',
#   'aqi': 77,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-05 23:50:03,350',
#   'serial': '1,40972',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 84,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 00:50:07,946',
#   'serial': '1,42260',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 88,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 01:50:09,589',
#   'serial': '1,43586',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 90,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 02:50:18,614',
#   'serial': '1,45041',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 94,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 03:50:19,771',
#   'serial': '1,46462',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '多云',
#   'aqi': 98,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 04:50:30,733',
#   'serial': '1,48109',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '阴',
#   'aqi': 97,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 05:50:35,538',
#   'serial': '1,49647',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '阴',
#   'aqi': 93,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 06:50:38,524',
#   'serial': '1,51437',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 87,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 07:50:41,421',
#   'serial': '1,53102',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 88,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 08:50:47,048',
#   'serial': '1,54509',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 84,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 09:50:49,127',
#   'serial': '1,55637',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 53,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-06 10:50:49,996',
#   'serial': '1,56763',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 11:50:51,230',
#   'serial': '1,57833',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 12:50:56,630',
#   'serial': '1,58873',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 13:51:00,214',
#   'serial': '1,59897',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 14:51:02,548',
#   'serial': '2,1027',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 15:51:05,156',
#   'serial': '2,2180',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 16:51:07,186',
#   'serial': '2,3370',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 17:51:08,455',
#   'serial': '2,4568',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 18:51:13,372',
#   'serial': '2,5765',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 19:51:16,012',
#   'serial': '2,7085',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 20:51:17,186',
#   'serial': '2,8352',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 21:51:21,778',
#   'serial': '2,9755',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 22:51:35,652',
#   'serial': '2,11279',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-06 23:51:37,364',
#   'serial': '2,12446',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 00:51:38,432',
#   'serial': '2,13796',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 01:51:40,433',
#   'serial': '2,15384',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 02:51:42,562',
#   'serial': '2,17305',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 03:51:44,405',
#   'serial': '2,19231',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 04:51:51,904',
#   'serial': '2,21141',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 05:51:53,456',
#   'serial': '2,22920',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 06:51:56,387',
#   'serial': '2,25079',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 07:51:57,648',
#   'serial': '2,27004',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 08:51:58,829',
#   'serial': '2,28366',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 09:52:02,829',
#   'serial': '2,29684',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 10:52:07,912',
#   'serial': '2,30859',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 11:52:13,306',
#   'serial': '2,31939',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 12:52:15,423',
#   'serial': '2,32968',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 13:52:17,025',
#   'serial': '2,34016',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 14:52:20,990',
#   'serial': '2,35311',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 15:52:24,858',
#   'serial': '2,36689',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 16:52:26,446',
#   'serial': '2,38201',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 17:52:32,423',
#   'serial': '2,39676',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 18:52:34,476',
#   'serial': '2,41040',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 30,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 19:52:37,473',
#   'serial': '2,42574',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 50,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 20:52:39,367',
#   'serial': '2,44168',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 61,
#   'pollutant': 'PM10'},
#  {'timestamp': '2024-02-07 21:52:43,365',
#   'serial': '2,45901',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 59,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-07 22:52:45,239',
#   'serial': '2,47642',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 34,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-07 23:52:49,007',
#   'serial': '2,49341',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 00:52:51,372',
#   'serial': '2,51120',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 01:52:53,017',
#   'serial': '2,53112',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 02:52:55,267',
#   'serial': '2,55269',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 03:52:56,269',
#   'serial': '2,57491',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 04:52:57,381',
#   'serial': '2,58725',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 05:52:59,139',
#   'serial': '2,59834',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-6°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 06:53:05,753',
#   'serial': '3,1034',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 21,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 07:53:09,320',
#   'serial': '3,2116',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '多云',
#   'aqi': 20,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 08:53:12,019',
#   'serial': '3,3134',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 19,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 09:53:15,534',
#   'serial': '3,4137',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '多云',
#   'aqi': 20,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 10:53:19,933',
#   'serial': '3,5135',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 11:53:25,683',
#   'serial': '3,6139',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 12:53:27,170',
#   'serial': '3,7154',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 13:53:29,337',
#   'serial': '3,8177',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 14:53:32,361',
#   'serial': '3,9157',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 15:53:33,635',
#   'serial': '3,10251',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 16:53:34,490',
#   'serial': '3,11347',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 17:53:41,839',
#   'serial': '3,12437',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 18:53:54,018',
#   'serial': '3,13572',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 32,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-08 19:53:58,075',
#   'serial': '3,14693',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 51,
#   'pollutant': 'PM10'},
#  {'timestamp': '2024-02-08 20:54:00,878',
#   'serial': '3,15855',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 58,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-08 21:54:17,612',
#   'serial': '3,17057',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 69,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-08 22:54:23,336',
#   'serial': '3,18263',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-08 23:54:25,258',
#   'serial': '3,19496',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 79,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 00:54:26,978',
#   'serial': '3,20714',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 75,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 01:54:30,234',
#   'serial': '3,21858',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 69,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 02:54:34,488',
#   'serial': '3,23139',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 65,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 03:54:36,714',
#   'serial': '3,24569',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 63,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 04:54:42,650',
#   'serial': '3,25866',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 55,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 05:54:44,270',
#   'serial': '3,27119',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 57,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 06:54:46,004',
#   'serial': '3,28582',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 60,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 07:54:47,668',
#   'serial': '3,29882',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 59,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 08:54:49,287',
#   'serial': '3,31051',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 53,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 09:54:54,161',
#   'serial': '3,32095',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 57,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 10:54:55,866',
#   'serial': '3,33187',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 70,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 11:54:57,877',
#   'serial': '3,34269',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 12:54:58,938',
#   'serial': '3,35268',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 80,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 13:55:06,179',
#   'serial': '3,36295',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 82,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 14:55:10,269',
#   'serial': '3,37370',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 15:55:26,389',
#   'serial': '3,38601',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': 67,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-09 16:55:28,287',
#   'serial': '3,39776',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 51,
#   'pollutant': 'PM10'},
#  {'timestamp': '2024-02-09 17:55:37,286',
#   'serial': '3,40998',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 49,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-09 18:55:43,631',
#   'serial': '3,42339',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 43,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-09 19:55:50,085',
#   'serial': '3,43681',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 29,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-09 20:55:54,430',
#   'serial': '3,44900',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 35,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-09 21:55:57,214',
#   'serial': '3,46196',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-09 22:56:04,925',
#   'serial': '3,47593',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-09 23:56:06,284',
#   'serial': '3,48860',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 00:56:08,102',
#   'serial': '3,50049',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 01:56:09,393',
#   'serial': '3,51336',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 02:56:14,004',
#   'serial': '3,52820',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 03:56:16,595',
#   'serial': '3,54198',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 04:56:18,958',
#   'serial': '3,55612',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 30,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 05:56:20,451',
#   'serial': '3,57008',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 06:56:21,929',
#   'serial': '3,58653',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 07:56:25,501',
#   'serial': '4,489',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-5°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 08:56:27,647',
#   'serial': '4,1868',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 09:56:29,364',
#   'serial': '4,2957',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 10:56:37,480',
#   'serial': '4,3977',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 11:56:49,096',
#   'serial': '4,4990',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 31,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 12:56:54,515',
#   'serial': '4,5975',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 33,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 13:56:59,013',
#   'serial': '4,7015',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 34,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 14:57:02,719',
#   'serial': '4,8138',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 34,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 15:57:06,002',
#   'serial': '4,9363',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 36,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 16:57:08,079',
#   'serial': '4,10432',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 36,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 17:57:16,043',
#   'serial': '4,11534',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 45,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-10 18:57:19,897',
#   'serial': '4,12634',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 56,
#   'pollutant': 'PM10'},
#  {'timestamp': '2024-02-10 19:57:35,463',
#   'serial': '4,13674',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 74,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-10 20:57:39,666',
#   'serial': '4,14827',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 79,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-10 21:57:42,088',
#   'serial': '4,15920',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 77,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-10 22:57:45,325',
#   'serial': '4,17044',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 80,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-10 23:57:47,975',
#   'serial': '4,18099',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 82,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 00:57:49,182',
#   'serial': '4,19133',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 85,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 01:57:51,784',
#   'serial': '4,20097',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 90,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 02:57:55,260',
#   'serial': '4,21143',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 93,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 03:57:59,660',
#   'serial': '4,22186',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 95,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 04:58:06,434',
#   'serial': '4,23285',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '晴',
#   'aqi': 103,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 05:58:08,445',
#   'serial': '4,24275',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '晴',
#   'aqi': 107,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 06:58:14,728',
#   'serial': '4,25328',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 108,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 07:58:20,116',
#   'serial': '4,26418',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '多云',
#   'aqi': 105,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 08:58:30,726',
#   'serial': '4,27430',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 97,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 09:58:35,827',
#   'serial': '4,28417',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '多云',
#   'aqi': 89,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 10:58:39,389',
#   'serial': '4,29410',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 95,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 11:58:41,798',
#   'serial': '4,30391',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '晴',
#   'aqi': 72,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 12:58:44,883',
#   'serial': '4,31328',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '晴',
#   'aqi': 59,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 13:58:53,550',
#   'serial': '4,32318',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '晴',
#   'aqi': 63,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 14:59:03,983',
#   'serial': '4,33342',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 68,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 15:59:07,700',
#   'serial': '4,34406',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 62,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 16:59:08,990',
#   'serial': '4,35511',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 55,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 17:59:10,198',
#   'serial': '4,36570',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 63,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 18:59:13,109',
#   'serial': '4,37652',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': 70,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 19:59:17,678',
#   'serial': '4,38733',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 74,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 20:59:19,723',
#   'serial': '4,39763',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 21:59:22,338',
#   'serial': '4,40759',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 22:59:26,693',
#   'serial': '4,41775',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 83,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-11 23:59:28,353',
#   'serial': '4,42807',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 85,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 00:59:31,077',
#   'serial': '4,43831',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 78,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 01:59:32,501',
#   'serial': '4,44807',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 70,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 02:59:38,980',
#   'serial': '4,45820',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 68,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 03:59:41,598',
#   'serial': '4,46792',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 68,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 04:59:45,412',
#   'serial': '4,47762',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 67,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 05:59:48,397',
#   'serial': '4,48787',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 59,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 06:59:49,687',
#   'serial': '4,49803',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 58,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 07:59:51,491',
#   'serial': '4,50823',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 64,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 08:59:57,394',
#   'serial': '4,51845',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 68,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 10:00:02,804',
#   'serial': '4,52842',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 72,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 11:00:04,588',
#   'serial': '4,53841',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': 87,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 12:00:11,403',
#   'serial': '4,54819',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 95,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 13:00:17,796',
#   'serial': '4,55793',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 122,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 14:00:21,600',
#   'serial': '4,56798',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 134,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 15:00:31,952',
#   'serial': '4,57840',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 128,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 16:00:37,283',
#   'serial': '4,58933',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 130,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 17:00:39,893',
#   'serial': '4,59941',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 129,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 18:00:42,144',
#   'serial': '5,1008',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '11°C',
#   'weather': '晴',
#   'aqi': 130,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 19:00:44,247',
#   'serial': '5,2077',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 132,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 20:00:48,148',
#   'serial': '5,3078',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': 132,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 21:00:58,162',
#   'serial': '5,4079',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 130,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 22:01:02,629',
#   'serial': '5,5175',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 135,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-12 23:01:04,951',
#   'serial': '5,6219',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 140,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 00:01:09,521',
#   'serial': '5,7264',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 138,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 01:01:14,769',
#   'serial': '5,8256',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 125,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 02:01:22,514',
#   'serial': '5,9254',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 124,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 03:01:29,924',
#   'serial': '5,10388',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 128,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 04:01:34,787',
#   'serial': '5,11457',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 129,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 05:01:37,694',
#   'serial': '5,12487',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 128,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 06:01:40,307',
#   'serial': '5,13567',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 123,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 07:01:44,659',
#   'serial': '5,14653',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 118,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 08:01:47,518',
#   'serial': '5,15716',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': 115,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 09:01:49,352',
#   'serial': '5,16721',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 117,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 10:01:56,836',
#   'serial': '5,17725',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': 122,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 11:01:58,997',
#   'serial': '5,18757',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': 139,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 12:01:59,951',
#   'serial': '5,19734',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '晴',
#   'aqi': 153,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 13:02:03,151',
#   'serial': '5,20768',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '12°C',
#   'weather': '晴',
#   'aqi': 153,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 14:02:06,580',
#   'serial': '5,21751',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '14°C',
#   'weather': '晴',
#   'aqi': 148,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 15:02:13,564',
#   'serial': '5,22794',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '15°C',
#   'weather': '晴',
#   'aqi': 139,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 16:02:16,061',
#   'serial': '5,23794',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '14°C',
#   'weather': '晴',
#   'aqi': 137,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 17:02:19,543',
#   'serial': '5,24777',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '14°C',
#   'weather': '晴',
#   'aqi': 138,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 18:02:28,273',
#   'serial': '5,25782',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '晴',
#   'aqi': 137,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 19:02:31,189',
#   'serial': '5,26737',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '阴',
#   'aqi': 142,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 20:02:34,729',
#   'serial': '5,27738',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '阴',
#   'aqi': 150,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 21:02:36,133',
#   'serial': '5,28746',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': 156,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 22:02:39,306',
#   'serial': '5,29782',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '多云',
#   'aqi': 158,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-13 23:02:45,047',
#   'serial': '5,30864',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 159,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 00:02:47,164',
#   'serial': '5,31920',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 155,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 01:02:52,224',
#   'serial': '5,32971',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '霾',
#   'aqi': 153,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 02:03:04,824',
#   'serial': '5,34000',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '霾',
#   'aqi': 149,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 03:03:06,838',
#   'serial': '5,35053',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '阴',
#   'aqi': 142,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 04:03:16,417',
#   'serial': '5,36068',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 142,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 05:03:19,893',
#   'serial': '5,37126',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': 143,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 06:03:29,539',
#   'serial': '5,38145',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '阴',
#   'aqi': 139,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 07:03:32,188',
#   'serial': '5,39252',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': 117,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 08:03:39,456',
#   'serial': '5,40279',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '阴',
#   'aqi': 79,
#   'pollutant': 'PM2.5'},
#  {'timestamp': '2024-02-14 09:03:40,626',
#   'serial': '5,41296',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '多云',
#   'aqi': 41,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 10:03:46,762',
#   'serial': '5,42296',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '多云',
#   'aqi': 32,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 11:03:58,574',
#   'serial': '5,43321',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 12:04:00,592',
#   'serial': '5,44298',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '多云',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 13:04:02,648',
#   'serial': '5,45320',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '多云',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 14:04:09,082',
#   'serial': '5,46314',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '多云',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 15:04:10,692',
#   'serial': '5,47345',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '多云',
#   'aqi': 28,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 16:04:16,095',
#   'serial': '5,48319',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '多云',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 17:04:19,261',
#   'serial': '5,49321',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '多云',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 18:04:21,885',
#   'serial': '5,50295',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '多云',
#   'aqi': 25,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 19:04:26,171',
#   'serial': '5,51274',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '阴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 20:04:31,766',
#   'serial': '5,52260',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '阴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 21:04:36,228',
#   'serial': '5,53254',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '阴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 22:04:42,624',
#   'serial': '5,54310',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-14 23:04:45,084',
#   'serial': '5,55368',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '多云',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 00:04:46,770',
#   'serial': '5,56360',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '多云',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 01:04:49,545',
#   'serial': '5,57388',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '多云',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 02:04:51,513',
#   'serial': '5,58466',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '阴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 03:04:54,857',
#   'serial': '5,59524',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '多云',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 04:05:00,015',
#   'serial': '6,525',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 05:05:01,857',
#   'serial': '6,1582',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '多云',
#   'aqi': 22,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 06:05:03,320',
#   'serial': '6,2536',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '多云',
#   'aqi': 20,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 07:05:05,899',
#   'serial': '6,3632',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '晴',
#   'aqi': 20,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 08:05:07,476',
#   'serial': '6,4628',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '晴',
#   'aqi': 18,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 09:05:18,275',
#   'serial': '6,5610',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': 18,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 10:05:33,498',
#   'serial': '6,6550',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '晴',
#   'aqi': 19,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 11:05:34,621',
#   'serial': '6,7466',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 23,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 12:05:42,548',
#   'serial': '6,8431',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 24,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 13:05:45,123',
#   'serial': '6,9407',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 14:05:48,572',
#   'serial': '6,10335',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 15:05:52,647',
#   'serial': '6,11288',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 27,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 16:05:56,698',
#   'serial': '6,12349',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': 26,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 17:06:01,670',
#   'serial': '6,13376',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': 30,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 18:06:02,814',
#   'serial': '6,14377',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': 35,
#   'pollutant': 'NA'},
#  {'timestamp': '2024-02-15 19:06:04,500',
#   'serial': '6,15398',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': 39,
#   'pollutant': 'NA'}]

# %%
import pandas as pd

# Create a DataFrame from the merged data
df = pd.DataFrame(merged_data)

# Save the DataFrame to a CSV file
df.to_csv('merged_data.csv', index=False)

# %%
from datetime import datetime

# Define the directory to scan for files
directory_path = 'raw_data/after 2.15'


# Function to parse the provided data structure within a file
def parse_data_structure(file_content):
    data_pattern = re.compile(
        r'Serial Data: (?P<serial>.+?)\n'
        r'Collect Time: (?P<timestamp>.+?)\n'
        r'City Name: (?P<city>.+?)\n'
        r'Location ID: (?P<location_id>.+?)\n'
        r'Temperature: (?P<temperature>.+?)\n'
        r'Weather: (?P<weather>.+?)\n'
        r'AQI: (?P<aqi>.+?)\n'
        r'Primary Pollutant: (?P<pollutant>.+?)\n',
        re.DOTALL
    )

    return [match.groupdict() for match in data_pattern.finditer(file_content)]

# Function to parse their contents
# Function to parse the contents of files in a directory
def parse_files(directory):
    # List to hold the parsed data
    parsed_data = []

    # Walk through the directory
    for root, dirs, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                parsed_data.extend(parse_data_structure(content))

    return parsed_data

file_content = parse_files(directory_path)
file_content
# Out:
# [{'serial': '1,51657',
#   'timestamp': '2024-02-20 00:12:06.480656',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '阴',
#   'aqi': '22',
#   'pollutant': 'NA'},
#  {'serial': '1,52666',
#   'timestamp': '2024-02-20 01:12:08.777382',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '多云',
#   'aqi': '22',
#   'pollutant': 'NA'},
#  {'serial': '1,53602',
#   'timestamp': '2024-02-20 02:12:25.365690',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': '22',
#   'pollutant': 'NA'},
#  {'serial': '1,54629',
#   'timestamp': '2024-02-20 03:12:27.299127',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '多云',
#   'aqi': '22',
#   'pollutant': 'NA'},
#  {'serial': '1,55644',
#   'timestamp': '2024-02-20 04:12:28.871388',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': '22',
#   'pollutant': 'NA'},
#  {'serial': '1,56654',
#   'timestamp': '2024-02-20 05:12:38.833959',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': '22',
#   'pollutant': 'NA'},
#  {'serial': '1,57686',
#   'timestamp': '2024-02-20 06:12:41.140928',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': '23',
#   'pollutant': 'NA'},
#  {'serial': '1,58732',
#   'timestamp': '2024-02-20 07:12:44.130022',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '阴',
#   'aqi': '22',
#   'pollutant': 'NA'},
#  {'serial': '1,59736',
#   'timestamp': '2024-02-20 08:12:57.893512',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-4°C',
#   'weather': '阴',
#   'aqi': '21',
#   'pollutant': 'NA'},
#  {'serial': '2,789',
#   'timestamp': '2024-02-20 09:13:01.978140',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '阴',
#   'aqi': '21',
#   'pollutant': 'NA'},
#  {'serial': '2,1808',
#   'timestamp': '2024-02-20 10:13:06.136324',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': '21',
#   'pollutant': 'NA'},
#  {'serial': '2,2842',
#   'timestamp': '2024-02-20 11:13:12.950056',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': '25',
#   'pollutant': 'NA'},
#  {'serial': '2,3882',
#   'timestamp': '2024-02-20 12:13:16.351758',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': '28',
#   'pollutant': 'NA'},
#  {'serial': '2,4935',
#   'timestamp': '2024-02-20 13:13:28.002215',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '阴',
#   'aqi': '27',
#   'pollutant': 'NA'},
#  {'serial': '0,59278',
#   'timestamp': '2024-02-18 00:08:48.250380',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '多云',
#   'aqi': '99',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,520',
#   'timestamp': '2024-02-18 01:08:50.746392',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '多云',
#   'aqi': '100',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,1605',
#   'timestamp': '2024-02-18 02:08:51.876518',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '多云',
#   'aqi': '103',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,2738',
#   'timestamp': '2024-02-18 03:08:53.080365',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '阴',
#   'aqi': '109',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,3974',
#   'timestamp': '2024-02-18 04:08:59.730116',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '多云',
#   'aqi': '115',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,5256',
#   'timestamp': '2024-02-18 05:09:03.161661',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '多云',
#   'aqi': '120',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,6466',
#   'timestamp': '2024-02-18 06:09:04.906720',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '多云',
#   'aqi': '122',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,7660',
#   'timestamp': '2024-02-18 07:09:14.524783',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '多云',
#   'aqi': '122',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,8792',
#   'timestamp': '2024-02-18 08:09:16.828333',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '阴',
#   'aqi': '119',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,9840',
#   'timestamp': '2024-02-18 09:09:22.357990',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '小雨',
#   'aqi': '110',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,10987',
#   'timestamp': '2024-02-18 10:09:23.299824',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '阴',
#   'aqi': '114',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,12112',
#   'timestamp': '2024-02-18 11:09:26.087885',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '阴',
#   'aqi': '118',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,13253',
#   'timestamp': '2024-02-18 12:09:31.527256',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '阴',
#   'aqi': '118',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,14313',
#   'timestamp': '2024-02-18 13:09:38.093529',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '阴',
#   'aqi': '124',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,15468',
#   'timestamp': '2024-02-18 14:09:39.406646',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '阴',
#   'aqi': '124',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,16548',
#   'timestamp': '2024-02-18 15:09:44.481699',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '阴',
#   'aqi': '125',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,17637',
#   'timestamp': '2024-02-18 16:09:51.997885',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '阴',
#   'aqi': '122',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,18720',
#   'timestamp': '2024-02-18 17:09:56.590550',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '阴',
#   'aqi': '90',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,19845',
#   'timestamp': '2024-02-18 18:09:58.850903',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '多云',
#   'aqi': '36',
#   'pollutant': 'NA'},
#  {'serial': '1,20963',
#   'timestamp': '2024-02-18 19:10:03.214534',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '阴',
#   'aqi': '26',
#   'pollutant': 'NA'},
#  {'serial': '1,22023',
#   'timestamp': '2024-02-18 20:10:09.204243',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '阴',
#   'aqi': '22',
#   'pollutant': 'NA'},
#  {'serial': '1,23096',
#   'timestamp': '2024-02-18 21:10:14.605850',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '阴',
#   'aqi': '23',
#   'pollutant': 'NA'},
#  {'serial': '1,24146',
#   'timestamp': '2024-02-18 22:10:16.657214',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '阴',
#   'aqi': '26',
#   'pollutant': 'NA'},
#  {'serial': '1,25175',
#   'timestamp': '2024-02-18 23:10:24.930149',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '阴',
#   'aqi': '35',
#   'pollutant': 'NA'},
#  {'serial': '0,2645',
#   'timestamp': '2024-02-16 00:05:55.451265',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': '58',
#   'pollutant': 'PM10'},
#  {'serial': '0,3834',
#   'timestamp': '2024-02-16 01:05:58.661464',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': '64',
#   'pollutant': 'PM10'},
#  {'serial': '0,5052',
#   'timestamp': '2024-02-16 02:06:00.028105',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': '67',
#   'pollutant': 'PM10'},
#  {'serial': '0,6250',
#   'timestamp': '2024-02-16 03:06:01.441236',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': '67',
#   'pollutant': 'PM10'},
#  {'serial': '0,7507',
#   'timestamp': '2024-02-16 04:06:04.674461',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': '65',
#   'pollutant': 'PM10'},
#  {'serial': '0,8792',
#   'timestamp': '2024-02-16 05:06:07.819623',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': '63',
#   'pollutant': 'PM10'},
#  {'serial': '0,10089',
#   'timestamp': '2024-02-16 06:06:09.704286',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '晴',
#   'aqi': '59',
#   'pollutant': 'PM10'},
#  {'serial': '0,11287',
#   'timestamp': '2024-02-16 07:06:14.958572',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-3°C',
#   'weather': '晴',
#   'aqi': '54',
#   'pollutant': 'PM10'},
#  {'serial': '0,12537',
#   'timestamp': '2024-02-16 08:06:20.241281',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-2°C',
#   'weather': '晴',
#   'aqi': '53',
#   'pollutant': 'PM10'},
#  {'serial': '0,13750',
#   'timestamp': '2024-02-16 09:06:21.651525',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': '56',
#   'pollutant': 'PM10'},
#  {'serial': '0,14890',
#   'timestamp': '2024-02-16 10:06:25.696268',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': '56',
#   'pollutant': 'PM10'},
#  {'serial': '0,16100',
#   'timestamp': '2024-02-16 11:06:29.324216',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': '58',
#   'pollutant': 'PM10'},
#  {'serial': '0,17252',
#   'timestamp': '2024-02-16 12:06:39.264296',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '晴',
#   'aqi': '61',
#   'pollutant': 'PM10'},
#  {'serial': '0,18296',
#   'timestamp': '2024-02-16 13:06:52.870652',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': '64',
#   'pollutant': 'PM10'},
#  {'serial': '0,19334',
#   'timestamp': '2024-02-16 14:06:56.277031',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': '64',
#   'pollutant': 'PM10'},
#  {'serial': '0,20453',
#   'timestamp': '2024-02-16 15:06:58.352291',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': '65',
#   'pollutant': 'PM10'},
#  {'serial': '0,21565',
#   'timestamp': '2024-02-16 16:07:02.227684',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': '68',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,22753',
#   'timestamp': '2024-02-16 17:07:11.044998',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': '72',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,23842',
#   'timestamp': '2024-02-16 18:07:14.369411',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '晴',
#   'aqi': '74',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,24925',
#   'timestamp': '2024-02-16 19:07:15.556235',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': '82',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,26032',
#   'timestamp': '2024-02-16 20:07:19.468243',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': '87',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,27218',
#   'timestamp': '2024-02-16 21:07:21.375148',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': '90',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,28388',
#   'timestamp': '2024-02-16 22:07:23.381041',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': '93',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,29631',
#   'timestamp': '2024-02-16 23:07:24.450443',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': '93',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,30840',
#   'timestamp': '2024-02-17 00:07:31.107756',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '晴',
#   'aqi': '89',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,32040',
#   'timestamp': '2024-02-17 01:07:33.321629',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '晴',
#   'aqi': '87',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,33274',
#   'timestamp': '2024-02-17 02:07:35.280524',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '晴',
#   'aqi': '87',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,34528',
#   'timestamp': '2024-02-17 03:07:39.501654',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': '85',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,35781',
#   'timestamp': '2024-02-17 04:07:40.633054',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': '88',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,37010',
#   'timestamp': '2024-02-17 05:07:44.594405',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': '94',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,38221',
#   'timestamp': '2024-02-17 06:07:46.284454',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '晴',
#   'aqi': '97',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,39452',
#   'timestamp': '2024-02-17 07:07:48.133697',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '多云',
#   'aqi': '95',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,40724',
#   'timestamp': '2024-02-17 08:07:53.161139',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '-1°C',
#   'weather': '多云',
#   'aqi': '94',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,41941',
#   'timestamp': '2024-02-17 09:07:55.755019',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': '94',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,43132',
#   'timestamp': '2024-02-17 10:08:02.241536',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '98',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,44299',
#   'timestamp': '2024-02-17 11:08:14.392394',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '6°C',
#   'weather': '多云',
#   'aqi': '107',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,45459',
#   'timestamp': '2024-02-17 12:08:17.285386',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '7°C',
#   'weather': '晴',
#   'aqi': '108',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,46509',
#   'timestamp': '2024-02-17 13:08:20.524082',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': '102',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,47672',
#   'timestamp': '2024-02-17 14:08:22.359756',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '多云',
#   'aqi': '95',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,48806',
#   'timestamp': '2024-02-17 15:08:24.554772',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '10°C',
#   'weather': '晴',
#   'aqi': '90',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,49958',
#   'timestamp': '2024-02-17 16:08:25.687014',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': '84',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,51143',
#   'timestamp': '2024-02-17 17:08:31.325636',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '9°C',
#   'weather': '晴',
#   'aqi': '83',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,52265',
#   'timestamp': '2024-02-17 18:08:33.083784',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '8°C',
#   'weather': '晴',
#   'aqi': '82',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,53355',
#   'timestamp': '2024-02-17 19:08:34.843231',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '5°C',
#   'weather': '多云',
#   'aqi': '83',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,54516',
#   'timestamp': '2024-02-17 20:08:40.113325',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '87',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,55713',
#   'timestamp': '2024-02-17 21:08:43.585953',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '92',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,56869',
#   'timestamp': '2024-02-17 22:08:45.010060',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': '95',
#   'pollutant': 'PM2.5'},
#  {'serial': '0,58082',
#   'timestamp': '2024-02-17 23:08:46.535526',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '晴',
#   'aqi': '98',
#   'pollutant': 'PM2.5'},
#  {'serial': '1,26274',
#   'timestamp': '2024-02-19 00:10:29.565869',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '4°C',
#   'weather': '阴',
#   'aqi': '41',
#   'pollutant': 'NA'},
#  {'serial': '1,27344',
#   'timestamp': '2024-02-19 01:10:31.973083',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '阴',
#   'aqi': '45',
#   'pollutant': 'NA'},
#  {'serial': '1,28460',
#   'timestamp': '2024-02-19 02:10:34.327543',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '阴',
#   'aqi': '47',
#   'pollutant': 'NA'},
#  {'serial': '1,29562',
#   'timestamp': '2024-02-19 03:10:36.460585',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '阴',
#   'aqi': '52',
#   'pollutant': 'PM10'},
#  {'serial': '1,30664',
#   'timestamp': '2024-02-19 04:10:40.806544',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '阴',
#   'aqi': '56',
#   'pollutant': 'PM10'},
#  {'serial': '1,31763',
#   'timestamp': '2024-02-19 05:10:50.131183',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '58',
#   'pollutant': 'PM10'},
#  {'serial': '1,32778',
#   'timestamp': '2024-02-19 06:10:53.446455',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '58',
#   'pollutant': 'PM10'},
#  {'serial': '1,33835',
#   'timestamp': '2024-02-19 07:10:56.053850',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '多云',
#   'aqi': '56',
#   'pollutant': 'PM10'},
#  {'serial': '1,34919',
#   'timestamp': '2024-02-19 08:10:57.941338',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '多云',
#   'aqi': '51',
#   'pollutant': 'PM10'},
#  {'serial': '1,35986',
#   'timestamp': '2024-02-19 09:11:02.603407',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '多云',
#   'aqi': '44',
#   'pollutant': 'NA'},
#  {'serial': '1,36989',
#   'timestamp': '2024-02-19 10:11:04.337781',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '多云',
#   'aqi': '41',
#   'pollutant': 'NA'},
#  {'serial': '1,38089',
#   'timestamp': '2024-02-19 11:11:06.059219',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '多云',
#   'aqi': '39',
#   'pollutant': 'NA'},
#  {'serial': '1,39098',
#   'timestamp': '2024-02-19 12:11:11.082995',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '37',
#   'pollutant': 'NA'},
#  {'serial': '1,40135',
#   'timestamp': '2024-02-19 13:11:16.730834',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '35',
#   'pollutant': 'NA'},
#  {'serial': '1,41176',
#   'timestamp': '2024-02-19 14:11:19.431201',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '35',
#   'pollutant': 'NA'},
#  {'serial': '1,42246',
#   'timestamp': '2024-02-19 15:11:22.344395',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '34',
#   'pollutant': 'NA'},
#  {'serial': '1,43248',
#   'timestamp': '2024-02-19 16:11:30.940560',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '3°C',
#   'weather': '多云',
#   'aqi': '34',
#   'pollutant': 'NA'},
#  {'serial': '1,44326',
#   'timestamp': '2024-02-19 17:11:41.985168',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '多云',
#   'aqi': '32',
#   'pollutant': 'NA'},
#  {'serial': '1,45364',
#   'timestamp': '2024-02-19 18:11:44.963677',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '多云',
#   'aqi': '32',
#   'pollutant': 'NA'},
#  {'serial': '1,46416',
#   'timestamp': '2024-02-19 19:11:51.770979',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '多云',
#   'aqi': '31',
#   'pollutant': 'NA'},
#  {'serial': '1,47438',
#   'timestamp': '2024-02-19 20:11:54.771316',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '2°C',
#   'weather': '多云',
#   'aqi': '30',
#   'pollutant': 'NA'},
#  {'serial': '1,48475',
#   'timestamp': '2024-02-19 21:11:55.891903',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '1°C',
#   'weather': '阴',
#   'aqi': '27',
#   'pollutant': 'NA'},
#  {'serial': '1,49541',
#   'timestamp': '2024-02-19 22:11:57.667056',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '多云',
#   'aqi': '22',
#   'pollutant': 'NA'},
#  {'serial': '1,50605',
#   'timestamp': '2024-02-19 23:12:05.064381',
#   'city': '海淀',
#   'location_id': '101010200',
#   'temperature': '0°C',
#   'weather': '多云',
#   'aqi': '22',
#   'pollutant': 'NA'}]

# %%
# Convert to csv
df = pd.DataFrame(file_content)
# df.to_csv('parsed_data.csv', index=False)

# Exchange pos of 2nd col(timestamp) & 1st col(serial)
df = df[['timestamp', 'serial', 'city', 'location_id', 'temperature', 'weather', 'aqi', 'pollutant']]
# df.to_csv('parsed_data.csv', index=False)

# Save in an existing csv file, but match the headers
df.to_csv('merged_data.csv', mode='a', header=False, index=False)
